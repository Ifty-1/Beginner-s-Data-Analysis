# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("adult.csv")
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <ipython-input-4-aa4f4450a243>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %% [markdown]
# 1.Here most positive rlationship is between educaional-num and hours-per-week,

# %%
df["gender"].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
X = df["age"]
Y = df["fnlwgt"]

plt.scatter(X, Y)
plt.xlabel("Age")
plt.ylabel("fnlwgt")
plt.show()

# %%
plt.pie(df[["race"]].value_counts().values, autopct='%1.1f%%')
plt.legend(df[["race"]].value_counts().index)

# %%
X = df["age"]
Y = df["hours-per-week"]

plt.scatter(X, Y)
plt.xlabel("Age")
plt.ylabel("hours-per-week")
plt.show()

# %%
sns.countplot(df, x="gender", hue="relationship")
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %% [markdown]
# # 1.Here harizatal X showing the gender of (male and female )
# # 2. Vartical line Y showing the count value of, How many  relationship occurs
# # colors shows
